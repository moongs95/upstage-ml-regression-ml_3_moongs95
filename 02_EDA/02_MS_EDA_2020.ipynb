# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
train = pd.read_csv('train_for_eda.csv')
train
# Out:
#                   시군구     번지     아파트명   전용면적(㎡)    계약년월  계약일   층  건축년도  \
# 0       서울특별시 강남구 개포동  651-1  개포더샵트리에  105.8064  202306   29   8  2021
# 1       서울특별시 강남구 개포동    187  개포주공5단지   74.2500  202301    3  10  1983
# 2       서울특별시 강남구 개포동    187  개포주공5단지   61.1900  202302    5  12  1983
# 3       서울특별시 강남구 개포동    187  개포주공5단지   83.1700  202304    7  13  1983
# 4       서울특별시 강남구 개포동    187  개포주공5단지   83.1700  202304   29  10  1983
# ...               ...    ...      ...       ...     ...  ...  ..   ...
# 155918  서울특별시 종로구 숭인동    2-1   종로센트레빌   59.9200  202008   24   8  2008
# 155919   서울특별시 중구 묵정동  11-67       묵정   52.4600  202001   17   5  1981
# 155920   서울특별시 중구 묵정동  11-67       묵정   52.4600  202001   22   2  1981
# 155921   서울특별시 중구 묵정동  11-67       묵정   52.4600  202003   31   2  1981
# 155922   서울특별시 중구 묵정동  11-67       묵정   52.4600  202007   31   8  1981
#
#                좌표X        좌표Y  ...    구  회사채금리 매매가격지수  건설공사비지수  버스정류장수  지하철수  \
# ...

# %%
train
# Out:
#                   시군구     번지     아파트명   전용면적(㎡)    계약년월  계약일   층  건축년도  \
# 0       서울특별시 강남구 개포동  651-1  개포더샵트리에  105.8064  202306   29   8  2021
# 1       서울특별시 강남구 개포동    187  개포주공5단지   74.2500  202301    3  10  1983
# 2       서울특별시 강남구 개포동    187  개포주공5단지   61.1900  202302    5  12  1983
# 3       서울특별시 강남구 개포동    187  개포주공5단지   83.1700  202304    7  13  1983
# 4       서울특별시 강남구 개포동    187  개포주공5단지   83.1700  202304   29  10  1983
# ...               ...    ...      ...       ...     ...  ...  ..   ...
# 155918  서울특별시 종로구 숭인동    2-1   종로센트레빌   59.9200  202008   24   8  2008
# 155919   서울특별시 중구 묵정동  11-67       묵정   52.4600  202001   17   5  1981
# 155920   서울특별시 중구 묵정동  11-67       묵정   52.4600  202001   22   2  1981
# 155921   서울특별시 중구 묵정동  11-67       묵정   52.4600  202003   31   2  1981
# 155922   서울특별시 중구 묵정동  11-67       묵정   52.4600  202007   31   8  1981
#
#                좌표X        좌표Y  ...    구  회사채금리 매매가격지수  건설공사비지수  버스정류장수  지하철수  \
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

plt.rcParams['font.family'] ='NanumGothic'
plt.rcParams['axes.unicode_minus'] =False

floor_mean = train.groupby('층')['target'].agg(가격 = 'mean').reset_index()

# 4. 그래프 그리기
plt.figure(figsize=(10,6))
sns.barplot(data=floor_mean, x='층', y='가격', color='skyblue')
plt.xlabel("층수")
plt.ylabel("층별 평균 매매가")
plt.title("층수 별 아파트 평균 매매가", fontsize=16)
plt.xticks(rotation= 90)
plt.show()

# %%
plt.figure(figsize=(10,6))

sns.histplot(data=train, x='건축년도', binwidth=1, color='pink', edgecolor='black')

plt.title("아파트 건축년도 히스토그램", fontsize=16)
plt.show()

# %%
plt.figure(figsize=(10,6))

sns.histplot(train['연식'],  color='pink', binwidth = 1)

plt.title("주택연식 분포 히스토그램", fontsize=16)
plt.show()

# %%
train[train['아파트명'].str.contains("e", na=False)]
# Out:
#                   시군구       번지       아파트명   전용면적(㎡)    계약년월  계약일   층  건축년도  \
# 466     서울특별시 강남구 논현동    195-1     e-편한세상   84.9876  202306    5   9  2005
# 1313    서울특별시 강남구 역삼동    755-4     e-편한세상   59.6060  202302   11  11  2005
# 1314    서울특별시 강남구 역삼동    755-4     e-편한세상   59.6060  202302   11  10  2005
# 1315    서울특별시 강남구 역삼동    755-4     e-편한세상   59.6060  202302   25  10  2005
# 1316    서울특별시 강남구 역삼동    755-4     e-편한세상   84.9910  202302   27   5  2005
# ...               ...      ...        ...       ...     ...  ...  ..   ...
# 154250  서울특별시 중랑구 중화동    19-16        한솔e   71.3400  202007   24   2  2004
# 154251  서울특별시 중랑구 중화동     19-3        한솔e   54.5400  202006   29   6  2004
# 154252  서울특별시 중랑구 중화동     19-3        한솔e   77.8500  202007    3   2  2004
# 155039  서울특별시 서초구 서초동  1467-37  서초3차e편한세상  158.2400  202010    9   4  2005
# 155040  서울특별시 서초구 서초동  1467-37  서초3차e편한세상  158.2400  202104   30   8  2005
#
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize = (10,5))
sns.boxplot(x=train['전용면적(㎡)'], color = 'yellow')
plt.title("전용면적 이상치")
plt.show()

# %%
plt.figure(figsize=(10,4))
sns.boxplot(x=train['target'], color = 'yellow')
plt.title("거래가격 이상치")
plt.show()

# %%
plt.figure(figsize=(10,4))
sns.boxplot(x=train['층'], color = 'yellow')
plt.title("층 이상치")
plt.show()

# %%
plt.figure(figsize=(10,4))
sns.violinplot(x=train['층'], color = 'yellow')
plt.title("층 이상치")
plt.show()

# %%
plt.figure(figsize=(10,4))
sns.violinplot(x=train['target'], color = 'yellow')
plt.title("거래가격 이상치")
plt.show()

# %%
plt.figure(figsize=(10,4))
sns.violinplot(x=train['전용면적(㎡)'], color = 'yellow')
plt.title("전용면적 이상치")
plt.show()

# %%
plt.figure(figsize=(10,4))
sns.histplot(train['버스정류장수'], bins=30, kde=True)
plt.title("버스정류장수 분포")
plt.show()

# %%
plt.figure(figsize=(10,4))
sns.histplot(train['지하철수'], bins=30, kde=True)
plt.title("지하철수 분포")
plt.show()

# %%
import matplotlib.ticker as mtick
plt.figure(figsize=(10,6))
sns.scatterplot(data=train, x='버스정류장수', y='target', alpha=0.5, color = 'salmon')
plt.title("버스정류장수와 거래가격 산점도")
plt.xlabel('버스정류장수')
plt.ylabel('거래가격')

plt.gca().yaxis.set_major_formatter(mtick.FuncFormatter(lambda x, _: f'{int(x):,}'))
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(data=train, x='지하철수', y='target', alpha=0.5, color = 'salmon')
plt.title("지하철수와 거래가격 산점도")
plt.xlabel('지하철수')
plt.ylabel('거래가격')
plt.show()

# %%
train.loc[train['연식'] < 0, '연식'] = 0

# %%
train[train['연식'] ==  0]
# Out:
#                   시군구    번지         아파트명  전용면적(㎡)    계약년월  계약일   층  건축년도  \
# 319     서울특별시 강남구 개포동   189    개포자이프레지던스   59.980  202304   24  15  2023
# 320     서울특별시 강남구 개포동   189    개포자이프레지던스   59.980  202305   13  23  2023
# 321     서울특별시 강남구 개포동   189    개포자이프레지던스   78.330  202306   30   9  2023
# 1331    서울특별시 강남구 역삼동   902    강남센트럴아이파크   84.915  202210    6   8  2022
# 1332    서울특별시 강남구 역삼동   902    강남센트럴아이파크  125.462  202211   16  18  2022
# ...               ...   ...          ...      ...     ...  ...  ..   ...
# 154646  서울특별시 강남구 개포동  1282    개포래미안포레스트   59.920  202011   26  17  2020
# 154647  서울특별시 강남구 개포동  1282    개포래미안포레스트   59.920  202012   23   5  2020
# 154679  서울특별시 강남구 일원동   742     디에이치포레센트  101.940  202101   24  11  2021
# 154680  서울특별시 강남구 일원동   742     디에이치포레센트   84.940  202103    8   5  2021
# 155275  서울특별시 은평구 수색동   417  DMC롯데캐슬더퍼스트   84.970  202011    9  11  2021
#
#                좌표X        좌표Y  ...    구  회사채금리 매매가격지수  건설공사비지수  버스정류장수  지하철수  \
# ...

# %%
# 동 뺄지 말지 결정중 
'''train['시군구'] = train['시군구'].str.split(' ').str[-1]
train = train.rename(columns={'시군구': '동'})
train'''
# Out:
# "train['시군구'] = train['시군구'].str.split(' ').str[-1]\ntrain = train.rename(columns={'시군구': '동'})\ntrain"

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10,6))
sns.histplot(train['전용면적(㎡)'], bins=50, kde=True)
plt.xlabel('전용면적(㎡)')
plt.title('아파트 전용면적 분포')
plt.show()

# %%
# 정규성 필요없음
from scipy.stats import spearmanr

corr, p_value = spearmanr(train['강남권여부'], train['target'])
print("Spearman 상관계수:", corr)
print("p-value:", p_value)
# Out:
# Spearman 상관계수: 0.2236334966981953
# p-value: 0.0

# %%
# 상관분석 의미 없음
# 시군구, 계약년, 계약월,

# %%
train = train.drop(['계약일', '계약월', '계약년'], axis = 1)
train
# Out:
#                   시군구     번지     아파트명   전용면적(㎡)    계약년월   층  건축년도         좌표X  \
# 0       서울특별시 강남구 개포동  651-1  개포더샵트리에  105.8064  202306   8  2021  127.056394
# 1       서울특별시 강남구 개포동    187  개포주공5단지   74.2500  202301  10  1983  127.068028
# 2       서울특별시 강남구 개포동    187  개포주공5단지   61.1900  202302  12  1983  127.068028
# 3       서울특별시 강남구 개포동    187  개포주공5단지   83.1700  202304  13  1983  127.068028
# 4       서울특별시 강남구 개포동    187  개포주공5단지   83.1700  202304  10  1983  127.068028
# ...               ...    ...      ...       ...     ...  ..   ...         ...
# 155918  서울특별시 종로구 숭인동    2-1   종로센트레빌   59.9200  202008   8  2008  127.015931
# 155919   서울특별시 중구 묵정동  11-67       묵정   52.4600  202001   5  1981  127.000071
# 155920   서울특별시 중구 묵정동  11-67       묵정   52.4600  202001   2  1981  127.000071
# 155921   서울특별시 중구 묵정동  11-67       묵정   52.4600  202003   2  1981  127.000071
# 155922   서울특별시 중구 묵정동  11-67       묵정   52.4600  202007   8  1981  127.000071
#
# ...

# %%
# 층 그룹핑 -> 가격확인 및 상관분석 다시 돌리기
# 아파트명 그룹핑 -> 라벨 인코딩해서 상관분석
# 층 그룹핑 

def floor(x):
    if x <= 5:
        return "5층 이하"
    elif 5 < x < 15:
        return "6층 이상 15층 이하"
    else:
        return "16층 이상"

train["층구분"] = train['층'].apply(floor)

print(train['층구분'].value_counts())
train.head()
# Out:
# 층구분
# 6층 이상 15층 이하    77038
# 5층 이하           51188
# 16층 이상          27697
# Name: count, dtype: int64
#              시군구     번지     아파트명   전용면적(㎡)    계약년월   층  건축년도         좌표X  \
# 0  서울특별시 강남구 개포동  651-1  개포더샵트리에  105.8064  202306   8  2021  127.056394
# 1  서울특별시 강남구 개포동    187  개포주공5단지   74.2500  202301  10  1983  127.068028
# 2  서울특별시 강남구 개포동    187  개포주공5단지   61.1900  202302  12  1983  127.068028
# 3  서울특별시 강남구 개포동    187  개포주공5단지   83.1700  202304  13  1983  127.068028
# 4  서울특별시 강남구 개포동    187  개포주공5단지   83.1700  202304  10  1983  127.068028
#
#          좌표Y  target                   주소    구  회사채금리  매매가격지수  건설공사비지수  \
# 0  37.484892  240000  서울특별시 강남구 개포동 651-1  강남구  4.356    92.7   127.42
# 1  37.487802  210000    서울특별시 강남구 개포동 187  강남구  4.704    94.6   127.10
# 2  37.487802  199000    서울특별시 강남구 개포동 187  강남구  4.274    93.6   127.16
# 3  37.487802  249000    서울특별시 강남구 개포동 187  강남구  4.072    92.6   127.45
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10,6))
sns.histplot(train['층구분'], bins=10)
plt.xlabel('층구분')
plt.title('층 구분 분포')
plt.show()

# %%
floor_price = train.groupby("층구분")["연식"].mean().reset_index()
print(floor_price)

import matplotlib.pyplot as plt

order = ["5층 이하", "6층 이상 15층 이하", "16층 이상"]
train["층구분"] = pd.Categorical(train["층구분"], categories=order, ordered=True)


floor_price = train.groupby("층구분")["연식"].mean().reset_index()

floor_price.plot(kind = 'bar', x = "층구분",  color= "#90ee90")

plt.title("층 구분별 평균 연식")
plt.xticks(rotation=25)
plt.savefig('층 구분별 평균 연식.png')
plt.show()

# plt.show()
# Out:
#             층구분         연식
# 0        16층 이상  15.824746
# 1         5층 이하  20.900289
# 2  6층 이상 15층 이하  19.498027

# %%
from scipy.stats import spearmanr

mapping = {"5층 이하" : 1, "6층 이상 15층 이하" : 2, "16층 이상": 3}
train["층구분_num"] = train["층구분"].map(mapping)

# 상관계수 계산

corr, pval = spearmanr(train["층구분_num"], train["target"])
print("corr", corr)
print("pval", pval)
# Out:
# corr 0.15547277984657587
# pval 0.0

# %%
test_df = pd.read_csv("test_for_eda.csv", encoding = "utf-8")
test_df.head()
# Out:
#              시군구     아파트명   전용면적(㎡)    계약년월   층  건축년도      도로명    구  회사채금리  \
# 0  서울특별시 강남구 개포동   개포6차우성   79.9700  202307   5  1987    언주로 3  강남구  4.437
# 1  서울특별시 강남구 개포동  개포더샵트리에  108.2017  202308  10  2021  개포로 311  강남구  4.500
# 2  서울특별시 강남구 개포동   개포우성3차  161.0000  202307  15  1984  개포로 307  강남구  4.437
# 3  서울특별시 강남구 개포동   개포우성3차  133.4600  202308  14  1984  개포로 307  강남구  4.500
# 4  서울특별시 강남구 개포동   개포우성3차  104.4300  202308   6  1984  개포로 307  강남구  4.500
#
#    매매가격지수  건설공사비지수  버스정류장수  지하철수   계약년  계약월  연식
# 0    93.0   127.33    86.0   2.0  2023    7  36
# 1    93.4   127.39    86.0   2.0  2023    8   2
# 2    93.0   127.33    86.0   2.0  2023    7  39
# 3    93.4   127.39    86.0   2.0  2023    8  39
# 4    93.4   127.39    86.0   2.0  2023    8  39

# %%
'''test_df['시군구'] = test_df['시군구'].str.split(' ').str[-1]
test_df = test_df.rename(columns={'시군구': '동'})
train'''
# Out:
# "test_df['시군구'] = test_df['시군구'].str.split(' ').str[-1]\ntest_df = test_df.rename(columns={'시군구': '동'})\ntrain"

# %%
train.head()
# Out:
#              시군구     번지     아파트명   전용면적(㎡)    계약년월   층  건축년도         좌표X  \
# 0  서울특별시 강남구 개포동  651-1  개포더샵트리에  105.8064  202306   8  2021  127.056394
# 1  서울특별시 강남구 개포동    187  개포주공5단지   74.2500  202301  10  1983  127.068028
# 2  서울특별시 강남구 개포동    187  개포주공5단지   61.1900  202302  12  1983  127.068028
# 3  서울특별시 강남구 개포동    187  개포주공5단지   83.1700  202304  13  1983  127.068028
# 4  서울특별시 강남구 개포동    187  개포주공5단지   83.1700  202304  10  1983  127.068028
#
#          좌표Y  target  ...    구  회사채금리  매매가격지수  건설공사비지수  버스정류장수  지하철수  강남권여부  \
# 0  37.484892  240000  ...  강남구  4.356    92.7   127.42    86.0   2.0      1
# 1  37.487802  210000  ...  강남구  4.704    94.6   127.10    86.0   2.0      1
# 2  37.487802  199000  ...  강남구  4.274    93.6   127.16    86.0   2.0      1
# 3  37.487802  249000  ...  강남구  4.072    92.6   127.45    86.0   2.0      1
# 4  37.487802  277000  ...  강남구  4.072    92.6   127.45    86.0   2.0      1
#
#    연식           층구분 층구분_num
# 0   2  6층 이상 15층 이하       2
# ...

# %%
train['강남권여부'] = train['구'].apply(lambda x: 1 if x in ['강남구', '서초구', '송파구'] else 0)
train[['구', '강남권여부']]
# Out:
#           구  강남권여부
# 0       강남구      1
# 1       강남구      1
# 2       강남구      1
# 3       강남구      1
# 4       강남구      1
# ...     ...    ...
# 155918  강동구      0
# 155919  강동구      0
# 155920  강동구      0
# 155921  강동구      0
# 155922  강동구      0
#
# [155923 rows x 2 columns]

# %%
test_df['강남권여부'] = test_df['구'].apply(lambda x: 1 if x in ['강남구', '서초구', '송파구'] else 0)
test_df[['구', '강남권여부']]
# Out:
#         구  강남권여부
# 0     강남구      1
# 1     강남구      1
# 2     강남구      1
# 3     강남구      1
# 4     강남구      1
# ...   ...    ...
# 9267  중랑구      0
# 9268  중랑구      0
# 9269  중랑구      0
# 9270  중랑구      0
# 9271  중랑구      0
#
# [9272 rows x 2 columns]

# %%
# train 데이터 열 추출
use_cols = ['구','강남권여부', '아파트명' , '전용면적(㎡)', '계약년월', '층', '건축년도', '연식', '회사채금리', '매매가격지수', '건설공사비지수', '버스정류장수', '지하철수', 'target']
train_df_origin = train.copy()
train = train[use_cols]
train.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[310], line 4
#       2 use_cols = ['구','강남권여부', '아파트명' , '전용면적(㎡)', '계약년월', '층', '건축년도', '연식', '회사채금리', '매매가격지수', '건설공사비지수', '버스정류장수', '지하철수', 'target']
#       3 train_df_origin = train.copy()
# ----> 4 train = train[use_cols]
#       5 train.head()
#
# File /usr/local/lib/python3.8/dist-packages/pandas/core/frame.py:3767, in DataFrame.__getitem__(self, key)
#    3765     if is_iterator(key):
#    3766         key = list(key)
# -> 3767     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3769 # take() does not accept boolean indexers
#    3770 if getattr(indexer, "dtype", None) == bool:
#
# File /usr/local/lib/python3.8/dist-packages/pandas/core/indexes/base.py:5877, in Index._get_indexer_strict(self, key, axis_name)
#    5874 else:
# ...

# %%
test_df
# Out:
#                 시군구      아파트명   전용면적(㎡)    계약년월   층  건축년도        도로명    구  \
# 0     서울특별시 강남구 개포동    개포6차우성   79.9700  202307   5  1987      언주로 3  강남구
# 1     서울특별시 강남구 개포동   개포더샵트리에  108.2017  202308  10  2021    개포로 311  강남구
# 2     서울특별시 강남구 개포동    개포우성3차  161.0000  202307  15  1984    개포로 307  강남구
# 3     서울특별시 강남구 개포동    개포우성3차  133.4600  202308  14  1984    개포로 307  강남구
# 4     서울특별시 강남구 개포동    개포우성3차  104.4300  202308   6  1984    개포로 307  강남구
# ...             ...       ...       ...     ...  ..   ...        ...  ...
# 9267  서울특별시 중랑구 신내동  신내우디안1단지   84.6500  202307  13  2014  신내역로1길 85  중랑구
# 9268  서울특별시 중랑구 신내동  신내우디안1단지   84.6200  202307  12  2014  신내역로1길 85  중랑구
# 9269  서울특별시 중랑구 신내동  신내우디안1단지  101.6500  202308  12  2014  신내역로1길 85  중랑구
# 9270  서울특별시 중랑구 신내동  신내우디안1단지   84.9400  202309  18  2014  신내역로1길 85  중랑구
# 9271  서울특별시 중랑구 신내동  신내우디안1단지   84.6500  202309  13  2014  신내역로1길 85  중랑구
#
#       회사채금리  매매가격지수  건설공사비지수  버스정류장수  지하철수   계약년  계약월  연식  강남권여부
# ...

# %%
# test 데이터 열 추출
use_cols = ['구', '강남권여부', '아파트명' , '전용면적(㎡)', '계약년월', '층', '건축년도', '연식', '회사채금리', '매매가격지수', '건설공사비지수', '버스정류장수', '지하철수']
test_df_origin = test_df.copy()
test_df = test_df[use_cols]
test_df.head()
# Out:
#      구  강남권여부     아파트명   전용면적(㎡)    계약년월   층  건축년도  연식  회사채금리  매매가격지수  \
# 0  강남구      1   개포6차우성   79.9700  202307   5  1987  36  4.437    93.0
# 1  강남구      1  개포더샵트리에  108.2017  202308  10  2021   2  4.500    93.4
# 2  강남구      1   개포우성3차  161.0000  202307  15  1984  39  4.437    93.0
# 3  강남구      1   개포우성3차  133.4600  202308  14  1984  39  4.500    93.4
# 4  강남구      1   개포우성3차  104.4300  202308   6  1984  39  4.500    93.4
#
#    건설공사비지수  버스정류장수  지하철수
# 0   127.33    86.0   2.0
# 1   127.39    86.0   2.0
# 2   127.33    86.0   2.0
# 3   127.39    86.0   2.0
# 4   127.39    86.0   2.0

# %%
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9272 entries, 0 to 9271
# Data columns (total 13 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   구        9272 non-null   object
#  1   강남권여부    9272 non-null   int64
#  2   아파트명     9262 non-null   object
#  3   전용면적(㎡)  9272 non-null   float64
#  4   계약년월     9272 non-null   int64
#  5   층        9272 non-null   int64
#  6   건축년도     9272 non-null   int64
#  7   연식       9272 non-null   int64
#  8   회사채금리    9272 non-null   float64
#  9   매매가격지수   9272 non-null   float64
#  10  건설공사비지수  9272 non-null   float64
#  11  버스정류장수   9272 non-null   float64
#  12  지하철수     7488 non-null   float64
# dtypes: float64(6), int64(5), object(2)
# memory usage: 941.8+ KB

# %%
train.head() # 값 확인
# Out:
#      구  강남권여부     아파트명   전용면적(㎡)    계약년월   층  건축년도  연식  회사채금리  매매가격지수  \
# 0  강남구      1  개포더샵트리에  105.8064  202306   8  2021   2  4.356    92.7
# 1  강남구      1  개포주공5단지   74.2500  202301  10  1983  40  4.704    94.6
# 2  강남구      1  개포주공5단지   61.1900  202302  12  1983  40  4.274    93.6
# 3  강남구      1  개포주공5단지   83.1700  202304  13  1983  40  4.072    92.6
# 4  강남구      1  개포주공5단지   83.1700  202304  10  1983  40  4.072    92.6
#
#    건설공사비지수  버스정류장수  지하철수  target
# 0   127.42    86.0   2.0  240000
# 1   127.10    86.0   2.0  210000
# 2   127.16    86.0   2.0  199000
# 3   127.45    86.0   2.0  249000
# 4   127.45    86.0   2.0  277000

# %%
bins = [-10, 5, 15, float('inf')]
labels = ["저층", "중층", "고층"]

train["층"] = pd.cut(train["층"], bins = bins, labels = labels)

print(train['층'].value_counts())
# Out:
# 층
# 중층    83027
# 저층    51188
# 고층    21708
# Name: count, dtype: int64
# /tmp/ipykernel_400834/1089476121.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train["층"] = pd.cut(train["층"], bins = bins, labels = labels)

# %%
bins = [-10, 5, 15, float('inf')]
labels = ["저층", "중층", "고층"]

test_df["층"] = pd.cut(test_df["층"], bins = bins, labels = labels)

print(floors.value_counts())
# Out:
# 층
# 중층    83027
# 저층    51188
# 고층    21708
# Name: count, dtype: int64
# /tmp/ipykernel_400834/3297187021.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df["층"] = pd.cut(test_df["층"], bins = bins, labels = labels)

# %%
# NaN이 있는지 여부 확인 (True/False)
nan_exists = train['층'].isnull().any()
print("아파트층에 NaN 값이 있나요?", nan_exists)

# NaN 값 개수 확인
nan_count = train['층'].isnull().sum()
print("아파트층에 NaN 값 개수:", nan_count)

# NaN 값이 있는 행 출력
nan_rows = train[train['층'].isnull()]
print("아파트층에 NaN 값이 있는 행들:\n", nan_rows)
# Out:
# 아파트층에 NaN 값이 있나요? False
# 아파트층에 NaN 값 개수: 0
# 아파트층에 NaN 값이 있는 행들:
#  Empty DataFrame
# Columns: [구, 강남권여부, 아파트명, 전용면적(㎡), 계약년월, 층, 건축년도, 연식, 회사채금리, 매매가격지수, 건설공사비지수, 버스정류장수, 지하철수, target]
# Index: []

# %%
# NaN이 있는지 여부 확인 (True/False)
nan_exists = test_df['층'].isnull().any()
print("아파트층에 NaN 값이 있나요?", nan_exists)

# NaN 값 개수 확인
nan_count = test_df['층'].isnull().sum()
print("아파트층에 NaN 값 개수:", nan_count)

# NaN 값이 있는 행 출력
nan_rows = test_df[test_df['층'].isnull()]
print("아파트층에 NaN 값이 있는 행들:\n", nan_rows)
# Out:
# 아파트층에 NaN 값이 있나요? False
# 아파트층에 NaN 값 개수: 0
# 아파트층에 NaN 값이 있는 행들:
#  Empty DataFrame
# Columns: [구, 강남권여부, 아파트명, 전용면적(㎡), 계약년월, 층, 건축년도, 연식, 회사채금리, 매매가격지수, 건설공사비지수, 버스정류장수, 지하철수]
# Index: []

# %%
test_df['층'] = test_df['층'].fillna('저층')
# Out:
# /tmp/ipykernel_400834/2168697330.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df['층'] = test_df['층'].fillna('저층')

# %%
use_cols = ['구', '브랜드명' , '전용면적(㎡)', '계약년월', '층', '건축년도', '연식', '회사채금리', '매매가격지수', '건설공사비지수', '버스정류장수', '지하철수', 'target']

# %%
import re
#train 아파트명 브랜드 범주화
brand_patterns = {
    "래미안": r"래미안|레미안",
    "힐스테이트": r"힐스테이트|디에이치",
    "자이": r"자이",
    "e편한세상": r"e-편한세상|이편한세상|e편한세상",
    "롯데캐슬": r"롯데캐슬|르엘",
    "아이파크": r"PARK",
    "푸르지오": r"푸르지오|써밋",
    "더샵": r"더샵",
    "센트레빌": r"센트레빌",
    "스위첸": r"스위첸",
    "유보라": r"유보라",
    "주공": r"주공|엘에이치|휴먼시아"
}
#train 아파트명 브랜드 범주화
#초기화
train['브랜드명'] = "일반"

#브랜드별로 매칭
for brand, pattern in brand_patterns.items():
    mask = train['아파트명'].str.contains(pattern, flags=re.IGNORECASE, regex=True)
    train.loc[mask, '브랜드명'] = brand

use_cols = ['구', '브랜드명', '전용면적(㎡)', '계약년월', '층', '건축년도', '연식', '회사채금리', '매매가격지수', '건설공사비지수', '버스정류장수', '지하철수', 'target']

train = train[use_cols]
train = train.rename(columns={'브랜드명' : '아파트명'})
# Out:
# /tmp/ipykernel_400834/1940091158.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train['브랜드명'] = "일반"

# %%
train['아파트명'].value_counts()
# Out:
# 아파트명
# 일반       120470
# 주공         8499
# 래미안        7922
# 힐스테이트      3871
# 푸르지오       3848
# 자이         3182
# e편한세상      2928
# 롯데캐슬       2715
# 센트레빌       1284
# 더샵          676
# 아이파크        400
# 스위첸          84
# 유보라          44
# Name: count, dtype: int64

# %%
# train['브랜드명'].value_counts()['래미안']

# %%
#train[train['브랜드명'] == '래미안']

# %%
train[train['아파트명'].str.contains(r'래미안|레미안')]
# Out:
#           구 아파트명  전용면적(㎡)    계약년월   층  건축년도  연식  회사채금리  매매가격지수  건설공사비지수  \
# 14      강남구  래미안   59.967  202210  중층  2019   3  5.436   101.4   125.60
# 15      강남구  래미안   84.943  202212  중층  2019   3  5.302    96.3   125.33
# 16      강남구  래미안   49.909  202301  중층  2019   4  4.704    94.6   127.10
# 17      강남구  래미안   59.897  202301  저층  2019   4  4.704    94.6   127.10
# 18      강남구  래미안   59.967  202301  고층  2019   4  4.704    94.6   127.10
# ...     ...  ...      ...     ...  ..   ...  ..    ...     ...      ...
# 155758  강동구  래미안   32.760  202008  중층  2001  19  2.192    95.8    99.35
# 155759  강동구  래미안   32.760  202009  중층  2001  19  2.239    96.1   100.64
# 155760  강동구  래미안   84.330  202009  저층  2001  19  2.239    96.1   100.64
# 155761  강동구  래미안   32.760  202009  중층  2001  19  2.239    96.1   100.64
# 155762  강동구  래미안   60.000  202009  저층  2001  19  2.239    96.1   100.64
#
#         버스정류장수  지하철수  target
# 14        86.0   2.0  185000
# 15        86.0   2.0  241000
# ...

# %%
import re
#train 아파트명 브랜드 범주화
brand_patterns = {
    "래미안": r"래미안|레미안",
    "힐스테이트": r"힐스테이트|디에이치",
    "자이": r"자이",
    "e편한세상": r"e-편한세상|이편한세상|e편한세상",
    "롯데캐슬": r"롯데캐슬|르엘",
    "아이파크": r"PARK",
    "푸르지오": r"푸르지오|써밋",
    "더샵": r"더샵",
    "센트레빌": r"센트레빌",
    "스위첸": r"스위첸",
    "유보라": r"유보라",
    "주공": r"주공|엘에이치|휴먼시아"
}
#train 아파트명 브랜드 범주화
#초기화
test_df['브랜드명'] = "일반"

#브랜드별로 매칭
for brand, pattern in brand_patterns.items():
    mask = train['아파트명'].str.contains(pattern, flags=re.IGNORECASE, regex=True)
    test_df.loc[mask, '브랜드명'] = brand

use_cols = ['구', '브랜드명', '전용면적(㎡)', '계약년월', '층', '건축년도', '연식', '회사채금리', '매매가격지수', '건설공사비지수', '버스정류장수', '지하철수']

test_df = test_df[use_cols]
test_df = test_df.rename(columns={'브랜드명' : '아파트명'})
# Out:
# /tmp/ipykernel_400834/974129953.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df['브랜드명'] = "일반"

# %%
test_df.head()
# Out:
#      구 아파트명   전용면적(㎡)    계약년월   층  건축년도  연식  회사채금리  매매가격지수  건설공사비지수  버스정류장수  \
# 0  강남구   더샵   79.9700  202307  저층  1987  36  4.437    93.0   127.33    86.0
# 1  강남구   주공  108.2017  202308  중층  2021   2  4.500    93.4   127.39    86.0
# 2  강남구   주공  161.0000  202307  중층  1984  39  4.437    93.0   127.33    86.0
# 3  강남구   주공  133.4600  202308  중층  1984  39  4.500    93.4   127.39    86.0
# 4  강남구   주공  104.4300  202308  중층  1984  39  4.500    93.4   127.39    86.0
#
#    지하철수
# 0   2.0
# 1   2.0
# 2   2.0
# 3   2.0
# 4   2.0

# %%
'''from sklearn.preprocessing import LabelEncoder

cols_to_encode = ['구', '층', '아파트명']

le = LabelEncoder()

for col in cols_to_encode:'''
# Out:
# "from sklearn.preprocessing import LabelEncoder\n\ncols_to_encode = ['구', '층', '아파트명']\n\nle = LabelEncoder()\n\nfor col in cols_to_encode:"

# %%
test_df['강남권여부'] = test_df['구'].apply(lambda x: 1 if x in ['강남구', '서초구', '송파구'] else 0)
test_df[['구', '강남권여부']]
# Out:
#         구  강남권여부
# 0     강남구      1
# 1     강남구      1
# 2     강남구      1
# 3     강남구      1
# 4     강남구      1
# ...   ...    ...
# 9267  중랑구      0
# 9268  중랑구      0
# 9269  중랑구      0
# 9270  중랑구      0
# 9271  중랑구      0
#
# [9272 rows x 2 columns]

# %%
# 생략없이 다보여주기 
#with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    #print(test_df[test_df['강남권여부'] == 1])

# %%
test_df[test_df['구'].isin(['용산구'])]
# Out:
#         구  아파트명  전용면적(㎡)    계약년월   층  건축년도  연식  회사채금리  매매가격지수  건설공사비지수  \
# 8254  용산구    일반   84.980  202307  중층  2001  22  4.437    93.0   127.33
# 8255  용산구    일반   84.980  202308  고층  2001  22  4.500    93.4   127.39
# 8256  용산구    일반   59.690  202307  중층  2001  22  4.437    93.0   127.33
# 8257  용산구    일반   59.690  202309  저층  2001  22  4.602    93.9   129.34
# 8258  용산구    일반   84.976  202308  고층  2014   9  4.500    93.4   127.39
# ...   ...   ...      ...     ...  ..   ...  ..    ...     ...      ...
# 8598  용산구  푸르지오   84.910  202309  저층  2018   5  4.602    93.9   129.34
# 8599  용산구  푸르지오   84.960  202307  저층  2002  21  4.437    93.0   127.33
# 8600  용산구  푸르지오   90.520  202309  저층  2003  20  4.602    93.9   129.34
# 8601  용산구  푸르지오  163.270  202309  저층  2004  19  4.602    93.9   129.34
# 8602  용산구  푸르지오   84.780  202308  저층  2004  19  4.500    93.4   127.39
#
#       버스정류장수  지하철수  강남권여부
# 8254     2.0   NaN      0
# 8255     2.0   NaN      0
# 8256     2.0   NaN      0
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# 로그 변환 후 히스토그램
fig = plt.figure(figsize=(10, 5))
sns.histplot(np.log1p(train['target']))  # log(1 + x)
plt.title("거래가격 분포 (로그 변환)", fontsize=14)
ax = plt.gca()
plt.show()

# %% [raw]
# # 범부화 데이터 인코딩 전
# # 데이터의 상관계수 행렬을 생성
# corr = train.corr(numeric_only=True, method='spearman')
# # figure에서 생략될 부분을 지정하는 mask 행렬을 생성 - 실제로는 mask 없이 다 생성해도 괜찮습니다.
# mask = np.ones_like(corr, dtype=bool)
# mask = np.triu(mask, k = 1)
#
# # 히트맵 형태로 상관행렬 시각화하기
# plt.figure(figsize=(13,10))
# sns.heatmap(data=corr, annot=True, fmt='.2f', mask=mask, linewidths=.5, cmap='RdYlBu_r')
# plt.title('Correlation Matrix')
# plt.show()

# %%
train_df_origin.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 155923 entries, 0 to 155922
# Data columns (total 21 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   시군구      155923 non-null  object
#  1   번지       155878 non-null  object
#  2   아파트명     155923 non-null  object
#  3   전용면적(㎡)  155923 non-null  float64
#  4   계약년월     155923 non-null  int64
#  5   층        155923 non-null  int64
#  6   건축년도     155923 non-null  int64
#  7   좌표X      36628 non-null   float64
#  8   좌표Y      36628 non-null   float64
#  9   target   155923 non-null  int64
#  10  주소       155878 non-null  object
#  11  구        155923 non-null  object
#  12  회사채금리    155923 non-null  float64
#  13  매매가격지수   155923 non-null  float64
#  14  건설공사비지수  155923 non-null  float64
#  15  버스정류장수   155923 non-null  float64
#  16  지하철수     155923 non-null  float64
#  17  강남권여부    155923 non-null  int64
#  18  연식       155923 non-null  int64
#  19  층구분      155923 non-null  category
# ...

# %%
# 라벨 인코딩 
'''from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()

cols_to_encode = ['구', '층', '아파트명']

for col in cols_to_encode:
    train[col] = le.fit_transform(train[col])

print(train[['구', '층',  '아파트명']].head())'''
# Out:
# "from sklearn.preprocessing import LabelEncoder\n\nle = LabelEncoder()\n\ncols_to_encode = ['구', '층', '아파트명']\n\nfor col in cols_to_encode:\n    train[col] = le.fit_transform(train[col])\n\nprint(train[['구', '층',  '아파트명']].head())"

# %%
test_df.to_csv('test_for_eda_2.csv', index = False)

# %%
train.to_csv('train_for_eda_2.csv', index=False)

# %%
# 로그스케일 필요없음
'''train['target_log'] = np.log1p(train['target'])
train[['target', 'target_log']].head()'''
# Out:
# "train['target_log'] = np.log1p(train['target'])\ntrain[['target', 'target_log']].head()"

# %%
# 범주화 데이터 인코딩 전
# 데이터의 상관계수 행렬을 생성
corr = train.corr(numeric_only=True, method='spearman')
# figure에서 생략될 부분을 지정하는 mask 행렬을 생성 - 실제로는 mask 없이 다 생성해도 괜찮습니다.
mask = np.ones_like(corr, dtype=bool)
mask = np.triu(mask, k = 1)

# 히트맵 형태로 상관행렬 시각화하기
plt.figure(figsize=(13,10))
sns.heatmap(data=corr, annot=True, fmt='.2f', mask=mask, linewidths=.5, cmap='RdYlBu_r')
plt.title('Correlation Matrix')
plt.show()
